# %% [markdown]
# # Image Classification
# In this project, you'll classify images from the [CIFAR-10 dataset](https://www.cs.toronto.edu/~kriz/cifar.html).  The dataset consists of airplanes, dogs, cats, and other objects. You'll preprocess the images, then train a convolutional neural network on all the samples. The images need to be normalized and the labels need to be one-hot encoded.  You'll get to apply what you learned and build a convolutional, max pooling, dropout, and fully connected layers.  At the end, you'll get to see your neural network's predictions on the sample images.
# ## Get the Data
# Run the following cell to download the [CIFAR-10 dataset for python](https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz).

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
from urllib.request import urlretrieve
from os.path import isfile, isdir
from tqdm import tqdm
import problem_unittests as tests
import tarfile

cifar10_dataset_folder_path = 'cifar-10-batches-py'

# Use Floyd's cifar-10 dataset if present
floyd_cifar10_location = '/input/cifar-10/python.tar.gz'
if isfile(floyd_cifar10_location):
    tar_gz_path = floyd_cifar10_location
else:
    tar_gz_path = 'cifar-10-python.tar.gz'

class DLProgress(tqdm):
    last_block = 0

    def hook(self, block_num=1, block_size=1, total_size=None):
        self.total = total_size
        self.update((block_num - self.last_block) * block_size)
        self.last_block = block_num

if not isfile(tar_gz_path):
    with DLProgress(unit='B', unit_scale=True, miniters=1, desc='CIFAR-10 Dataset') as pbar:
        urlretrieve(
            'https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz',
            tar_gz_path,
            pbar.hook)

if not isdir(cifar10_dataset_folder_path):
    with tarfile.open(tar_gz_path) as tar:
        tar.extractall()
        tar.close()


tests.test_folder_path(cifar10_dataset_folder_path)
# Out:
# All files found!

# %% [markdown]
# ## Explore the Data
# The dataset is broken into batches to prevent your machine from running out of memory.  The CIFAR-10 dataset consists of 5 batches, named `data_batch_1`, `data_batch_2`, etc.. Each batch contains the labels and images that are one of the following:
# * airplane
# * automobile
# * bird
# * cat
# * deer
# * dog
# * frog
# * horse
# * ship
# * truck
#
# Understanding a dataset is part of making predictions on the data.  Play around with the code cell below by changing the `batch_id` and `sample_id`. The `batch_id` is the id for a batch (1-5). The `sample_id` is the id for a image and label pair in the batch.
#
# Ask yourself "What are all possible labels?", "What is the range of values for the image data?", "Are the labels in order or random?".  Answers to questions like these will help you preprocess the data and end up with better predictions.

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import helper
import numpy as np

# Explore the dataset
batch_id = 1
sample_id = 5
helper.display_stats(cifar10_dataset_folder_path, batch_id, sample_id)
# Out:
# Stats of batch 1:
# Samples: 10000
# Label Counts: {0: 1005, 1: 974, 2: 1032, 3: 1016, 4: 999, 5: 937, 6: 1030, 7: 1001, 8: 1025, 9: 981}
# First 20 Labels: [6, 9, 9, 4, 1, 1, 2, 7, 8, 3, 4, 7, 7, 2, 9, 9, 9, 3, 2, 6]
#
# Example of Image 5:
# Image - Min Value: 0 Max Value: 252
# Image - Shape: (32, 32, 3)
# Label - Label Id: 1 Name: automobile

# %% [markdown]
# ## Implement Preprocess Functions
# ### Normalize
# In the cell below, implement the `normalize` function to take in image data, `x`, and return it as a normalized Numpy array. The values should be in the range of 0 to 1, inclusive.  The return object should be the same shape as `x`.

# %%
def normalize(x):
    """
    Normalize a list of sample image data in the range of 0 to 1
    : x: List of image data.  The image shape is (32, 32, 3)
    : return: Numpy array of normalize data
    """
    scale_min = 0.0
    interval = 1.0
    normalized_image = scale_min + (((x-0)/255)*interval)
    return normalized_image


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_normalize(normalize)
# Out:
# Tests Passed

# %% [markdown]
# ### One-hot encode
# Just like the previous code cell, you'll be implementing a function for preprocessing.  This time, you'll implement the `one_hot_encode` function. The input, `x`, are a list of labels.  Implement the function to return the list of labels as One-Hot encoded Numpy array.  The possible values for labels are 0 to 9. The one-hot encoding function should return the same encoding for each value between each call to `one_hot_encode`.  Make sure to save the map of encodings outside the function.
#
# Hint: Don't reinvent the wheel.

# %%
def one_hot_encode(x):
    """
    One hot encode a list of sample labels. Return a one-hot encoded vector for each label.
    : x: List of sample Labels
    : return: Numpy array of one-hot encoded labels
    """

    if type(x) == list:
        x = np.array(x)
    one_hot = np.array([[0]*10]*(x.shape[0]))
    for i in range(x.shape[0]):
        one_hot[i][x[i]] = 1

    return one_hot


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_one_hot_encode(one_hot_encode)
# Out:
# Tests Passed

# %% [markdown]
# ### Randomize Data
# As you saw from exploring the data above, the order of the samples are randomized.  It doesn't hurt to randomize it again, but you don't need to for this dataset.

# %% [markdown]
# ## Preprocess all the data and save it
# Running the code cell below will preprocess all the CIFAR-10 data and save it to file. The code below also uses 10% of the training data for validation.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
# Preprocess Training, Validation, and Testing Data
helper.preprocess_and_save_data(cifar10_dataset_folder_path, normalize, one_hot_encode)

# %% [markdown]
# # Check Point
# This is your first checkpoint.  If you ever decide to come back to this notebook or have to restart the notebook, you can start from here.  The preprocessed data has been saved to disk.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
import pickle
import problem_unittests as tests
import helper

# Load the Preprocessed Validation data
valid_features, valid_labels = pickle.load(open('preprocess_validation.p', mode='rb'))

# %% [markdown]
# ## Build the network
# For the neural network, you'll build each layer into a function.  Most of the code you've seen has been outside of functions. To test your code more thoroughly, we require that you put each layer in a function.  This allows us to give you better feedback and test for simple mistakes using our unittests before you submit your project.
#
# >**Note:** If you're finding it hard to dedicate enough time for this course each week, we've provided a small shortcut to this part of the project. In the next couple of problems, you'll have the option to use classes from the [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) packages to build each layer, except the layers you build in the "Convolutional and Max Pooling Layer" section.  TF Layers is similar to Keras's and TFLearn's abstraction to layers, so it's easy to pickup.
#
# >However, if you would like to get the most out of this course, try to solve all the problems _without_ using anything from the TF Layers packages. You **can** still use classes from other packages that happen to have the same name as ones you find in TF Layers! For example, instead of using the TF Layers version of the `conv2d` class, [tf.layers.conv2d](https://www.tensorflow.org/api_docs/python/tf/layers/conv2d), you would want to use the TF Neural Network version of `conv2d`, [tf.nn.conv2d](https://www.tensorflow.org/api_docs/python/tf/nn/conv2d).
#
# Let's begin!
#
# ### Input
# The neural network needs to read the image data, one-hot encoded labels, and dropout keep probability. Implement the following functions
# * Implement `neural_net_image_input`
#  * Return a [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder)
#  * Set the shape using `image_shape` with batch size set to `None`.
#  * Name the TensorFlow placeholder "x" using the TensorFlow `name` parameter in the [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder).
# * Implement `neural_net_label_input`
#  * Return a [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder)
#  * Set the shape using `n_classes` with batch size set to `None`.
#  * Name the TensorFlow placeholder "y" using the TensorFlow `name` parameter in the [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder).
# * Implement `neural_net_keep_prob_input`
#  * Return a [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder) for dropout keep probability.
#  * Name the TensorFlow placeholder "keep_prob" using the TensorFlow `name` parameter in the [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder).
#
# These names will be used at the end of the project to load your saved model.
#
# Note: `None` for shapes in TensorFlow allow for a dynamic size.

# %%
import tensorflow as tf

def neural_net_image_input(image_shape):
    """
    Return a Tensor for a batch of image input
    : image_shape: Shape of the images
    : return: Tensor for image input.
    """

    return tf.placeholder(tf.float32, [None, image_shape[0], image_shape[1], image_shape[2]], name = 'x')


def neural_net_label_input(n_classes):
    """
    Return a Tensor for a batch of label input
    : n_classes: Number of classes
    : return: Tensor for label input.
    """

    return tf.placeholder(tf.float32, [None, n_classes], name = 'y')


def neural_net_keep_prob_input():
    """
    Return a Tensor for keep probability
    : return: Tensor for keep probability.
    """

    return tf.placeholder(tf.float32, name = 'keep_prob')


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tf.reset_default_graph()
tests.test_nn_image_inputs(neural_net_image_input)
tests.test_nn_label_inputs(neural_net_label_input)
tests.test_nn_keep_prob_inputs(neural_net_keep_prob_input)
# Out:
# Image Input Tests Passed.
# Label Input Tests Passed.
# Keep Prob Tests Passed.

# %% [markdown]
# ### Convolution and Max Pooling Layer
# Convolution layers have a lot of success with images. For this code cell, you should implement the function `conv2d_maxpool` to apply convolution then max pooling:
# * Create the weight and bias using `conv_ksize`, `conv_num_outputs` and the shape of `x_tensor`.
# * Apply a convolution to `x_tensor` using weight and `conv_strides`.
#  * We recommend you use same padding, but you're welcome to use any padding.
# * Add bias
# * Add a nonlinear activation to the convolution.
# * Apply Max Pooling using `pool_ksize` and `pool_strides`.
#  * We recommend you use same padding, but you're welcome to use any padding.
#
# **Note:** You **can't** use [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) for **this** layer, but you can still use TensorFlow's [Neural Network](https://www.tensorflow.org/api_docs/python/tf/nn) package. You may still use the shortcut option for all the **other** layers.

# %%
def conv2d_maxpool(x_tensor, conv_num_outputs, conv_ksize, conv_strides, pool_ksize, pool_strides):
    """
    Apply convolution then max pooling to x_tensor
    :param x_tensor: TensorFlow Tensor
    :param conv_num_outputs: Number of outputs for the convolutional layer
    :param conv_ksize: kernal size 2-D Tuple for the convolutional layer
    :param conv_strides: Stride 2-D Tuple for convolution
    :param pool_ksize: kernal size 2-D Tuple for pool
    :param pool_strides: Stride 2-D Tuple for pool
    : return: A tensor that represents convolution and max pooling of x_tensor
    """

    # Weight and bias
    weight = tf.Variable(tf.truncated_normal([int(conv_ksize[0]), int(conv_ksize[1]), int(x_tensor.shape[3]) ,int(conv_num_outputs)], mean=0.0, stddev=0.1))
    bias = tf.Variable(tf.zeros([conv_num_outputs]))

    # Convolution
    conv = tf.nn.conv2d(x_tensor, weight, [1, int(conv_strides[0]), int(conv_strides[1]), 1], padding = 'SAME')
    conv = tf.nn.bias_add(conv, bias)

    # Pooling
    conv = tf.nn.max_pool(conv, [1 ,int(pool_ksize[0]), int(pool_ksize[1]), 1], [1, int(pool_strides[0]), (pool_strides[1]), 1], padding='SAME')
    conv = tf.nn.relu(conv)
    return conv


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_con_pool(conv2d_maxpool)
# Out:
# Tests Passed

# %% [markdown]
# ### Flatten Layer
# Implement the `flatten` function to change the dimension of `x_tensor` from a 4-D tensor to a 2-D tensor.  The output should be the shape (*Batch Size*, *Flattened Image Size*). Shortcut option: you can use classes from the [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) packages for this layer. For more of a challenge, only use other TensorFlow packages.

# %%
def flatten(x_tensor):
    """
    Flatten x_tensor to (Batch Size, Flattened Image Size)
    : x_tensor: A tensor of size (Batch Size, ...), where ... are the image dimensions.
    : return: A tensor of size (Batch Size, Flattened Image Size).
    """

    shape = x_tensor.get_shape().as_list()
    reshaped_x = tf.reshape(x_tensor, [-1, np.prod(shape[1:])])
    return reshaped_x


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_flatten(flatten)
# Out:
# Tests Passed

# %% [markdown]
# ### Fully-Connected Layer
# Implement the `fully_conn` function to apply a fully connected layer to `x_tensor` with the shape (*Batch Size*, *num_outputs*). Shortcut option: you can use classes from the [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) packages for this layer. For more of a challenge, only use other TensorFlow packages.

# %%
def fully_conn(x_tensor, num_outputs):
    """
    Apply a fully connected layer to x_tensor using weight and bias
    : x_tensor: A 2-D tensor where the first dimension is batch size.
    : num_outputs: The number of output that the new tensor should be.
    : return: A 2-D tensor where the second dimension is num_outputs.
    """
    weight = tf.Variable(tf.truncated_normal([int(x_tensor.shape[1]), num_outputs], mean=0.0, stddev=0.1))
    bias = tf.Variable(tf.zeros([num_outputs]))
    fc = tf.add(tf.matmul(x_tensor, weight), bias)
    fc = tf.nn.relu(fc)

    return fc


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_fully_conn(fully_conn)
# Out:
# Tests Passed

# %% [markdown]
# ### Output Layer
# Implement the `output` function to apply a fully connected layer to `x_tensor` with the shape (*Batch Size*, *num_outputs*). Shortcut option: you can use classes from the [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) packages for this layer. For more of a challenge, only use other TensorFlow packages.
#
# **Note:** Activation, softmax, or cross entropy should **not** be applied to this.

# %%
def output(x_tensor, num_outputs):
    """
    Apply a output layer to x_tensor using weight and bias
    : x_tensor: A 2-D tensor where the first dimension is batch size.
    : num_outputs: The number of output that the new tensor should be.
    : return: A 2-D tensor where the second dimension is num_outputs.
    """

    weight = tf.Variable(tf.truncated_normal([int(x_tensor.shape[1]), num_outputs], mean=0.0, stddev=0.1))
    bias = tf.Variable(tf.zeros([num_outputs]))
    out = tf.add(tf.matmul(x_tensor, weight), bias)
    return out

"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_output(output)

# %% [markdown]
# ### Create Convolutional Model
# Implement the function `conv_net` to create a convolutional neural network model. The function takes in a batch of images, `x`, and outputs logits.  Use the layers you created above to create this model:
#
# * Apply 1, 2, or 3 Convolution and Max Pool layers
# * Apply a Flatten Layer
# * Apply 1, 2, or 3 Fully Connected Layers
# * Apply an Output Layer
# * Return the output
# * Apply [TensorFlow's Dropout](https://www.tensorflow.org/api_docs/python/tf/nn/dropout) to one or more layers in the model using `keep_prob`.

# %%
def conv_net(x, keep_prob):
    """
    Create a convolutional neural network model
    : x: Placeholder tensor that holds image data.
    : keep_prob: Placeholder tensor that hold dropout keep probability.
    : return: Tensor that represents logits
    """
    # convolution parameters
    conv_ksize = (3, 3)
    conv_strides = (2, 2)
    pool_ksize = (2, 2)
    pool_strides = (2, 2)

    # Applying 2 convolutions and 2 maxpool
    conv1_num_outputs = 10
    conv1 = conv2d_maxpool(x, conv1_num_outputs, conv_ksize, conv_strides, pool_ksize, pool_strides)
    
    # Applying Second convolution Layer
    #conv2_num_outputs = 10
    #conv2 = conv2d_maxpool(conv1, conv2_num_outputs, conv_ksize, conv_strides, pool_ksize, pool_strides)
    
    # Applying flatten Layer
    flat = flatten(conv1)


    # Applying fully connected nodes
    fully_connected_1 = fully_conn(flat, 100)
    # Applying dropout
    fully_connected_1 = tf.nn.dropout(fully_connected_1, keep_prob)


    # Applying output layer
    out = output(fully_connected_1, 10)

    return out


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""

##############################
## Build the Neural Network ##
##############################

# Remove previous weights, bias, inputs, etc..
tf.reset_default_graph()

# Inputs
x = neural_net_image_input((32, 32, 3))
y = neural_net_label_input(10)
keep_prob = neural_net_keep_prob_input()

# Model
logits = conv_net(x, keep_prob)

# Name logits Tensor, so that is can be loaded from disk after training
logits = tf.identity(logits, name='logits')

# Loss and Optimizer
cost = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(logits=logits, labels=y))
optimizer = tf.train.AdamOptimizer().minimize(cost)

# Accuracy
correct_pred = tf.equal(tf.argmax(logits, 1), tf.argmax(y, 1))
accuracy = tf.reduce_mean(tf.cast(correct_pred, tf.float32), name='accuracy')

tests.test_conv_net(conv_net)
# Out:
# Neural Network Built!

# %% [markdown]
# ## Train the Neural Network
# ### Single Optimization
# Implement the function `train_neural_network` to do a single optimization.  The optimization should use `optimizer` to optimize in `session` with a `feed_dict` of the following:
# * `x` for image input
# * `y` for labels
# * `keep_prob` for keep probability for dropout
#
# This function will be called for each batch, so `tf.global_variables_initializer()` has already been called.
#
# Note: Nothing needs to be returned. This function is only optimizing the neural network.

# %%
def train_neural_network(session, optimizer, keep_probability, feature_batch, label_batch):
    """
    Optimize the session on a batch of images and labels
    : session: Current TensorFlow session
    : optimizer: TensorFlow optimizer function
    : keep_probability: keep probability
    : feature_batch: Batch of Numpy image data
    : label_batch: Batch of Numpy label data
    """

    session.run(optimizer, feed_dict={x:feature_batch, y:label_batch, keep_prob: keep_probability})


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_train_nn(train_neural_network)
# Out:
# Tests Passed

# %% [markdown]
# ### Show Stats
# Implement the function `print_stats` to print loss and validation accuracy.  Use the global variables `valid_features` and `valid_labels` to calculate validation accuracy.  Use a keep probability of `1.0` to calculate the loss and validation accuracy.

# %%
def print_stats(session, feature_batch, label_batch, cost, accuracy):
    """
    Print information about loss and validation accuracy
    : session: Current TensorFlow session
    : feature_batch: Batch of Numpy image data
    : label_batch: Batch of Numpy label data
    : cost: TensorFlow cost function
    : accuracy: TensorFlow accuracy function
    """
    # Running cost function to get the loss
    loss = session.run(cost, feed_dict={x:feature_batch, y:label_batch, keep_prob:1.0})

    # Running Accuracy function to get the accuracy
    accuracy = session.run(accuracy, feed_dict={x:valid_features, y:valid_labels, keep_prob:1.0})

    print('Loss: {:>10.4f} Validation Accuracy: {:.6f}'.format(loss, accuracy))

# %% [markdown]
# ### Hyperparameters
# Tune the following parameters:
# * Set `epochs` to the number of iterations until the network stops learning or start overfitting
# * Set `batch_size` to the highest number that your machine has memory for.  Most people set them to common sizes of memory:
#  * 64
#  * 128
#  * 256
#  * ...
# * Set `keep_probability` to the probability of keeping a node using dropout

# %%
# TODO: Tune Parameters
epochs = 80
batch_size = 128
keep_probability = 0.8

# %% [markdown]
# ### Train on a Single CIFAR-10 Batch
# Instead of training the neural network on all the CIFAR-10 batches of data, let's use a single batch. This should save time while you iterate on the model to get a better accuracy.  Once the final validation accuracy is 50% or greater, run the model on all the data in the next section.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
print('Checking the Training on a Single Batch...')
with tf.Session() as sess:
    # Initializing the variables
    sess.run(tf.global_variables_initializer())
    
    # Training cycle
    for epoch in range(epochs):
        batch_i = 1
        for batch_features, batch_labels in helper.load_preprocess_training_batch(batch_i, batch_size):
            train_neural_network(sess, optimizer, keep_probability, batch_features, batch_labels)
        print('Epoch {:>2}, CIFAR-10 Batch {}:  '.format(epoch + 1, batch_i), end='')
        print_stats(sess, batch_features, batch_labels, cost, accuracy)
# Out:
# Checking the Training on a Single Batch...
# Epoch  1, CIFAR-10 Batch 1:  Loss:     2.0386 Validation Accuracy: 0.283200
# Epoch  2, CIFAR-10 Batch 1:  Loss:     1.8298 Validation Accuracy: 0.380000
# Epoch  3, CIFAR-10 Batch 1:  Loss:     1.7270 Validation Accuracy: 0.412200
# Epoch  4, CIFAR-10 Batch 1:  Loss:     1.6862 Validation Accuracy: 0.431200
# Epoch  5, CIFAR-10 Batch 1:  Loss:     1.5756 Validation Accuracy: 0.447200
# Epoch  6, CIFAR-10 Batch 1:  Loss:     1.4964 Validation Accuracy: 0.465600
# Epoch  7, CIFAR-10 Batch 1:  Loss:     1.3863 Validation Accuracy: 0.477200
# Epoch  8, CIFAR-10 Batch 1:  Loss:     1.2899 Validation Accuracy: 0.495600
# Epoch  9, CIFAR-10 Batch 1:  Loss:     1.2191 Validation Accuracy: 0.499600
# Epoch 10, CIFAR-10 Batch 1:  Loss:     1.1150 Validation Accuracy: 0.497400
# Epoch 11, CIFAR-10 Batch 1:  Loss:     1.0703 Validation Accuracy: 0.501800
# Epoch 12, CIFAR-10 Batch 1:  Loss:     1.0094 Validation Accuracy: 0.507600
# Epoch 13, CIFAR-10 Batch 1:  Loss:     0.9314 Validation Accuracy: 0.504800
# Epoch 14, CIFAR-10 Batch 1:  Loss:     0.9000 Validation Accuracy: 0.509400
# Epoch 15, CIFAR-10 Batch 1:  Loss:     0.8369 Validation Accuracy: 0.505200
# Epoch 16, CIFAR-10 Batch 1:  Loss:     0.8260 Validation Accuracy: 0.516200
# Epoch 17, CIFAR-10 Batch 1:  Loss:     0.7638 Validation Accuracy: 0.515400
# Epoch 18, CIFAR-10 Batch 1:  Loss:     0.7365 Validation Accuracy: 0.510200
# Epoch 19, CIFAR-10 Batch 1:  Loss:     0.6804 Validation Accuracy: 0.511600
# Epoch 20, CIFAR-10 Batch 1:  Loss:     0.6516 Validation Accuracy: 0.507600
# Epoch 21, CIFAR-10 Batch 1:  Loss:     0.6225 Validation Accuracy: 0.513000
# Epoch 22, CIFAR-10 Batch 1:  Loss:     0.5936 Validation Accuracy: 0.514600
# Epoch 23, CIFAR-10 Batch 1:  Loss:     0.5580 Validation Accuracy: 0.517400
# Epoch 24, CIFAR-10 Batch 1:  Loss:     0.5351 Validation Accuracy: 0.518200
# Epoch 25, CIFAR-10 Batch 1:  Loss:     0.4795 Validation Accuracy: 0.525800
# Epoch 26, CIFAR-10 Batch 1:  Loss:     0.4678 Validation Accuracy: 0.521400
# Epoch 27, CIFAR-10 Batch 1:  Loss:     0.4552 Validation Accuracy: 0.525200
# Epoch 28, CIFAR-10 Batch 1:  Loss:     0.4278 Validation Accuracy: 0.519400
# Epoch 29, CIFAR-10 Batch 1:  Loss:     0.4149 Validation Accuracy: 0.515400
# Epoch 30, CIFAR-10 Batch 1:  Loss:     0.4021 Validation Accuracy: 0.532200
# Epoch 31, CIFAR-10 Batch 1:  Loss:     0.4202 Validation Accuracy: 0.523200
# Epoch 32, CIFAR-10 Batch 1:  Loss:     0.3920 Validation Accuracy: 0.536000
# Epoch 33, CIFAR-10 Batch 1:  Loss:     0.3776 Validation Accuracy: 0.524600
# Epoch 34, CIFAR-10 Batch 1:  Loss:     0.3827 Validation Accuracy: 0.528000
# Epoch 35, CIFAR-10 Batch 1:  Loss:     0.3691 Validation Accuracy: 0.525200
# Epoch 36, CIFAR-10 Batch 1:  Loss:     0.3420 Validation Accuracy: 0.533400
# Epoch 37, CIFAR-10 Batch 1:  Loss:     0.3226 Validation Accuracy: 0.520400
# Epoch 38, CIFAR-10 Batch 1:  Loss:     0.2950 Validation Accuracy: 0.528200
# Epoch 39, CIFAR-10 Batch 1:  Loss:     0.3045 Validation Accuracy: 0.530800
# Epoch 40, CIFAR-10 Batch 1:  Loss:     0.2785 Validation Accuracy: 0.527400
# Epoch 41, CIFAR-10 Batch 1:  Loss:     0.2683 Validation Accuracy: 0.526200
# Epoch 42, CIFAR-10 Batch 1:  Loss:     0.2519 Validation Accuracy: 0.527600
# Epoch 43, CIFAR-10 Batch 1:  Loss:     0.2357 Validation Accuracy: 0.529000
# Epoch 44, CIFAR-10 Batch 1:  Loss:     0.2424 Validation Accuracy: 0.524200
# Epoch 45, CIFAR-10 Batch 1:  Loss:     0.2200 Validation Accuracy: 0.524800
# Epoch 46, CIFAR-10 Batch 1:  Loss:     0.2053 Validation Accuracy: 0.528200
# Epoch 47, CIFAR-10 Batch 1:  Loss:     0.2061 Validation Accuracy: 0.532600
# Epoch 48, CIFAR-10 Batch 1:  Loss:     0.1802 Validation Accuracy: 0.530200
# Epoch 49, CIFAR-10 Batch 1:  Loss:     0.1711 Validation Accuracy: 0.532400
# Epoch 50, CIFAR-10 Batch 1:  Loss:     0.1601 Validation Accuracy: 0.537000
# Epoch 51, CIFAR-10 Batch 1:  Loss:     0.1471 Validation Accuracy: 0.531400
# Epoch 52, CIFAR-10 Batch 1:  Loss:     0.1500 Validation Accuracy: 0.528400
# Epoch 53, CIFAR-10 Batch 1:  Loss:     0.1344 Validation Accuracy: 0.529400
# Epoch 54, CIFAR-10 Batch 1:  Loss:     0.1222 Validation Accuracy: 0.529200
# Epoch 55, CIFAR-10 Batch 1:  Loss:     0.1365 Validation Accuracy: 0.526800
# Epoch 56, CIFAR-10 Batch 1:  Loss:     0.1108 Validation Accuracy: 0.532800
# Epoch 57, CIFAR-10 Batch 1:  Loss:     0.1180 Validation Accuracy: 0.529200
# Epoch 58, CIFAR-10 Batch 1:  Loss:     0.1054 Validation Accuracy: 0.528800
# Epoch 59, CIFAR-10 Batch 1:  Loss:     0.1058 Validation Accuracy: 0.528800
# Epoch 60, CIFAR-10 Batch 1:  Loss:     0.1020 Validation Accuracy: 0.527000
# Epoch 61, CIFAR-10 Batch 1:  Loss:     0.1021 Validation Accuracy: 0.527200
# Epoch 62, CIFAR-10 Batch 1:  Loss:     0.0940 Validation Accuracy: 0.529600
# Epoch 63, CIFAR-10 Batch 1:  Loss:     0.0846 Validation Accuracy: 0.531200
# Epoch 64, CIFAR-10 Batch 1:  Loss:     0.0783 Validation Accuracy: 0.530600
# Epoch 65, CIFAR-10 Batch 1:  Loss:     0.0881 Validation Accuracy: 0.525400
# Epoch 66, CIFAR-10 Batch 1:  Loss:     0.0751 Validation Accuracy: 0.521600
# Epoch 67, CIFAR-10 Batch 1:  Loss:     0.0723 Validation Accuracy: 0.525200
# Epoch 68, CIFAR-10 Batch 1:  Loss:     0.0753 Validation Accuracy: 0.522200
# Epoch 69, CIFAR-10 Batch 1:  Loss:     0.0681 Validation Accuracy: 0.523200
# Epoch 70, CIFAR-10 Batch 1:  Loss:     0.0647 Validation Accuracy: 0.524800
# Epoch 71, CIFAR-10 Batch 1:  Loss:     0.0694 Validation Accuracy: 0.522200
# Epoch 72, CIFAR-10 Batch 1:  Loss:     0.0632 Validation Accuracy: 0.517000
# Epoch 73, CIFAR-10 Batch 1:  Loss:     0.0648 Validation Accuracy: 0.518600
# Epoch 74, CIFAR-10 Batch 1:  Loss:     0.0659 Validation Accuracy: 0.512400
# Epoch 75, CIFAR-10 Batch 1:  Loss:     0.0548 Validation Accuracy: 0.520400
# Epoch 76, CIFAR-10 Batch 1:  Loss:     0.0587 Validation Accuracy: 0.517000
# Epoch 77, CIFAR-10 Batch 1:  Loss:     0.0675 Validation Accuracy: 0.511200
# Epoch 78, CIFAR-10 Batch 1:  Loss:     0.0509 Validation Accuracy: 0.528000
# Epoch 79, CIFAR-10 Batch 1:  Loss:     0.0599 Validation Accuracy: 0.515800
# Epoch 80, CIFAR-10 Batch 1:  Loss:     0.0548 Validation Accuracy: 0.514000

# %% [markdown]
# ### Fully Train the Model
# Now that you got a good accuracy with a single CIFAR-10 batch, try it with all five batches.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
save_model_path = './image_classification'

print('Training...')
with tf.Session() as sess:
    # Initializing the variables
    sess.run(tf.global_variables_initializer())
    
    # Training cycle
    for epoch in range(epochs):
        # Loop over all batches
        n_batches = 5
        for batch_i in range(1, n_batches + 1):
            for batch_features, batch_labels in helper.load_preprocess_training_batch(batch_i, batch_size):
                train_neural_network(sess, optimizer, keep_probability, batch_features, batch_labels)
            print('Epoch {:>2}, CIFAR-10 Batch {}:  '.format(epoch + 1, batch_i), end='')
            print_stats(sess, batch_features, batch_labels, cost, accuracy)
            
    # Save Model
    saver = tf.train.Saver()
    save_path = saver.save(sess, save_model_path)
# Out:
# Training...
# Epoch  1, CIFAR-10 Batch 1:  Loss:     2.1469 Validation Accuracy: 0.280200
# Epoch  1, CIFAR-10 Batch 2:  Loss:     1.8446 Validation Accuracy: 0.361200
# Epoch  1, CIFAR-10 Batch 3:  Loss:     1.5479 Validation Accuracy: 0.405400
# Epoch  1, CIFAR-10 Batch 4:  Loss:     1.6048 Validation Accuracy: 0.421200
# Epoch  1, CIFAR-10 Batch 5:  Loss:     1.6844 Validation Accuracy: 0.442800
# Epoch  2, CIFAR-10 Batch 1:  Loss:     1.8358 Validation Accuracy: 0.453400
# Epoch  2, CIFAR-10 Batch 2:  Loss:     1.4181 Validation Accuracy: 0.467600
# Epoch  2, CIFAR-10 Batch 3:  Loss:     1.2823 Validation Accuracy: 0.471400
# Epoch  2, CIFAR-10 Batch 4:  Loss:     1.3875 Validation Accuracy: 0.474600
# Epoch  2, CIFAR-10 Batch 5:  Loss:     1.4279 Validation Accuracy: 0.487200
# Epoch  3, CIFAR-10 Batch 1:  Loss:     1.6379 Validation Accuracy: 0.494000
# Epoch  3, CIFAR-10 Batch 2:  Loss:     1.2573 Validation Accuracy: 0.504400
# Epoch  3, CIFAR-10 Batch 3:  Loss:     1.1408 Validation Accuracy: 0.499800
# Epoch  3, CIFAR-10 Batch 4:  Loss:     1.2829 Validation Accuracy: 0.510400
# Epoch  3, CIFAR-10 Batch 5:  Loss:     1.3330 Validation Accuracy: 0.504600
# Epoch  4, CIFAR-10 Batch 1:  Loss:     1.5210 Validation Accuracy: 0.516400
# Epoch  4, CIFAR-10 Batch 2:  Loss:     1.1955 Validation Accuracy: 0.524600
# Epoch  4, CIFAR-10 Batch 3:  Loss:     1.0769 Validation Accuracy: 0.503400
# Epoch  4, CIFAR-10 Batch 4:  Loss:     1.2008 Validation Accuracy: 0.527000
# Epoch  4, CIFAR-10 Batch 5:  Loss:     1.2735 Validation Accuracy: 0.524200
# Epoch  5, CIFAR-10 Batch 1:  Loss:     1.5002 Validation Accuracy: 0.531600
# Epoch  5, CIFAR-10 Batch 2:  Loss:     1.0717 Validation Accuracy: 0.542400
# Epoch  5, CIFAR-10 Batch 3:  Loss:     0.9148 Validation Accuracy: 0.535600
# Epoch  5, CIFAR-10 Batch 4:  Loss:     1.1451 Validation Accuracy: 0.540800
# Epoch  5, CIFAR-10 Batch 5:  Loss:     1.1649 Validation Accuracy: 0.538000
# Epoch  6, CIFAR-10 Batch 1:  Loss:     1.3968 Validation Accuracy: 0.545400
# Epoch  6, CIFAR-10 Batch 2:  Loss:     1.0334 Validation Accuracy: 0.555000
# Epoch  6, CIFAR-10 Batch 3:  Loss:     0.8129 Validation Accuracy: 0.543400
# Epoch  6, CIFAR-10 Batch 4:  Loss:     1.0784 Validation Accuracy: 0.552800
# Epoch  6, CIFAR-10 Batch 5:  Loss:     1.0880 Validation Accuracy: 0.551600
# Epoch  7, CIFAR-10 Batch 1:  Loss:     1.3902 Validation Accuracy: 0.556800
# Epoch  7, CIFAR-10 Batch 2:  Loss:     1.0065 Validation Accuracy: 0.554600
# Epoch  7, CIFAR-10 Batch 3:  Loss:     0.7671 Validation Accuracy: 0.554000
# Epoch  7, CIFAR-10 Batch 4:  Loss:     1.0164 Validation Accuracy: 0.561000
# Epoch  7, CIFAR-10 Batch 5:  Loss:     1.0551 Validation Accuracy: 0.556000
# Epoch  8, CIFAR-10 Batch 1:  Loss:     1.2858 Validation Accuracy: 0.571800
# Epoch  8, CIFAR-10 Batch 2:  Loss:     0.9428 Validation Accuracy: 0.562000
# Epoch  8, CIFAR-10 Batch 3:  Loss:     0.7207 Validation Accuracy: 0.562800
# Epoch  8, CIFAR-10 Batch 4:  Loss:     0.9617 Validation Accuracy: 0.565400
# Epoch  8, CIFAR-10 Batch 5:  Loss:     0.9478 Validation Accuracy: 0.568600
# Epoch  9, CIFAR-10 Batch 1:  Loss:     1.1830 Validation Accuracy: 0.578400
# Epoch  9, CIFAR-10 Batch 2:  Loss:     0.8575 Validation Accuracy: 0.566400
# Epoch  9, CIFAR-10 Batch 3:  Loss:     0.6671 Validation Accuracy: 0.565200
# Epoch  9, CIFAR-10 Batch 4:  Loss:     0.9097 Validation Accuracy: 0.574600
# Epoch  9, CIFAR-10 Batch 5:  Loss:     0.8635 Validation Accuracy: 0.576200
# Epoch 10, CIFAR-10 Batch 1:  Loss:     1.1378 Validation Accuracy: 0.577400
# Epoch 10, CIFAR-10 Batch 2:  Loss:     0.8270 Validation Accuracy: 0.574600
# Epoch 10, CIFAR-10 Batch 3:  Loss:     0.6394 Validation Accuracy: 0.576400
# Epoch 10, CIFAR-10 Batch 4:  Loss:     0.8583 Validation Accuracy: 0.578400
# Epoch 10, CIFAR-10 Batch 5:  Loss:     0.8334 Validation Accuracy: 0.581200
# Epoch 11, CIFAR-10 Batch 1:  Loss:     1.0316 Validation Accuracy: 0.582800
# Epoch 11, CIFAR-10 Batch 2:  Loss:     0.7750 Validation Accuracy: 0.577400
# Epoch 11, CIFAR-10 Batch 3:  Loss:     0.6184 Validation Accuracy: 0.582200
# Epoch 11, CIFAR-10 Batch 4:  Loss:     0.7970 Validation Accuracy: 0.587600
# Epoch 11, CIFAR-10 Batch 5:  Loss:     0.7829 Validation Accuracy: 0.592200
# Epoch 12, CIFAR-10 Batch 1:  Loss:     0.9970 Validation Accuracy: 0.589600
# Epoch 12, CIFAR-10 Batch 2:  Loss:     0.7463 Validation Accuracy: 0.585600
# Epoch 12, CIFAR-10 Batch 3:  Loss:     0.6104 Validation Accuracy: 0.583600
# Epoch 12, CIFAR-10 Batch 4:  Loss:     0.7481 Validation Accuracy: 0.587800
# Epoch 12, CIFAR-10 Batch 5:  Loss:     0.6940 Validation Accuracy: 0.596400
# Epoch 13, CIFAR-10 Batch 1:  Loss:     0.9024 Validation Accuracy: 0.591600
# Epoch 13, CIFAR-10 Batch 2:  Loss:     0.6581 Validation Accuracy: 0.586800
# Epoch 13, CIFAR-10 Batch 3:  Loss:     0.5797 Validation Accuracy: 0.582600
# Epoch 13, CIFAR-10 Batch 4:  Loss:     0.7120 Validation Accuracy: 0.598200
# Epoch 13, CIFAR-10 Batch 5:  Loss:     0.6708 Validation Accuracy: 0.598400
# Epoch 14, CIFAR-10 Batch 1:  Loss:     0.9178 Validation Accuracy: 0.594800
# Epoch 14, CIFAR-10 Batch 2:  Loss:     0.6507 Validation Accuracy: 0.590600
# Epoch 14, CIFAR-10 Batch 3:  Loss:     0.5784 Validation Accuracy: 0.589000
# Epoch 14, CIFAR-10 Batch 4:  Loss:     0.6799 Validation Accuracy: 0.597600
# Epoch 14, CIFAR-10 Batch 5:  Loss:     0.6425 Validation Accuracy: 0.594600
# Epoch 15, CIFAR-10 Batch 1:  Loss:     0.8588 Validation Accuracy: 0.600600
# Epoch 15, CIFAR-10 Batch 2:  Loss:     0.6494 Validation Accuracy: 0.589000
# Epoch 15, CIFAR-10 Batch 3:  Loss:     0.5538 Validation Accuracy: 0.592000
# Epoch 15, CIFAR-10 Batch 4:  Loss:     0.6269 Validation Accuracy: 0.596200
# Epoch 15, CIFAR-10 Batch 5:  Loss:     0.6030 Validation Accuracy: 0.600800
# Epoch 16, CIFAR-10 Batch 1:  Loss:     0.7972 Validation Accuracy: 0.600000
# Epoch 16, CIFAR-10 Batch 2:  Loss:     0.6042 Validation Accuracy: 0.591800
# Epoch 16, CIFAR-10 Batch 3:  Loss:     0.5130 Validation Accuracy: 0.597200
# Epoch 16, CIFAR-10 Batch 4:  Loss:     0.6217 Validation Accuracy: 0.600400
# Epoch 16, CIFAR-10 Batch 5:  Loss:     0.5631 Validation Accuracy: 0.602000
# Epoch 17, CIFAR-10 Batch 1:  Loss:     0.7752 Validation Accuracy: 0.597200
# Epoch 17, CIFAR-10 Batch 2:  Loss:     0.5542 Validation Accuracy: 0.602000
# Epoch 17, CIFAR-10 Batch 3:  Loss:     0.4765 Validation Accuracy: 0.607600
# Epoch 17, CIFAR-10 Batch 4:  Loss:     0.5961 Validation Accuracy: 0.602000
# Epoch 17, CIFAR-10 Batch 5:  Loss:     0.5276 Validation Accuracy: 0.609400
# Epoch 18, CIFAR-10 Batch 1:  Loss:     0.7530 Validation Accuracy: 0.598400
# Epoch 18, CIFAR-10 Batch 2:  Loss:     0.5363 Validation Accuracy: 0.598200
# Epoch 18, CIFAR-10 Batch 3:  Loss:     0.4600 Validation Accuracy: 0.596400
# Epoch 18, CIFAR-10 Batch 4:  Loss:     0.5744 Validation Accuracy: 0.599200
# Epoch 18, CIFAR-10 Batch 5:  Loss:     0.5163 Validation Accuracy: 0.602200
# Epoch 19, CIFAR-10 Batch 1:  Loss:     0.7091 Validation Accuracy: 0.599400
# Epoch 19, CIFAR-10 Batch 2:  Loss:     0.5011 Validation Accuracy: 0.600200
# Epoch 19, CIFAR-10 Batch 3:  Loss:     0.4587 Validation Accuracy: 0.600600
# Epoch 19, CIFAR-10 Batch 4:  Loss:     0.5321 Validation Accuracy: 0.604800
# Epoch 19, CIFAR-10 Batch 5:  Loss:     0.5057 Validation Accuracy: 0.609600
# Epoch 20, CIFAR-10 Batch 1:  Loss:     0.6917 Validation Accuracy: 0.599800
# Epoch 20, CIFAR-10 Batch 2:  Loss:     0.5049 Validation Accuracy: 0.603400
# Epoch 20, CIFAR-10 Batch 3:  Loss:     0.4388 Validation Accuracy: 0.595000
# Epoch 20, CIFAR-10 Batch 4:  Loss:     0.5164 Validation Accuracy: 0.604400
# Epoch 20, CIFAR-10 Batch 5:  Loss:     0.4427 Validation Accuracy: 0.612200
# Epoch 21, CIFAR-10 Batch 1:  Loss:     0.6912 Validation Accuracy: 0.604000
# Epoch 21, CIFAR-10 Batch 2:  Loss:     0.4843 Validation Accuracy: 0.601000
# Epoch 21, CIFAR-10 Batch 3:  Loss:     0.4102 Validation Accuracy: 0.601600
# Epoch 21, CIFAR-10 Batch 4:  Loss:     0.5115 Validation Accuracy: 0.605600
# Epoch 21, CIFAR-10 Batch 5:  Loss:     0.4115 Validation Accuracy: 0.610200
# Epoch 22, CIFAR-10 Batch 1:  Loss:     0.6634 Validation Accuracy: 0.600000
# Epoch 22, CIFAR-10 Batch 2:  Loss:     0.4862 Validation Accuracy: 0.603400
# Epoch 22, CIFAR-10 Batch 3:  Loss:     0.3810 Validation Accuracy: 0.604600
# Epoch 22, CIFAR-10 Batch 4:  Loss:     0.4895 Validation Accuracy: 0.609200
# Epoch 22, CIFAR-10 Batch 5:  Loss:     0.4140 Validation Accuracy: 0.608200
# Epoch 23, CIFAR-10 Batch 1:  Loss:     0.6555 Validation Accuracy: 0.601200
# Epoch 23, CIFAR-10 Batch 2:  Loss:     0.4210 Validation Accuracy: 0.607000
# Epoch 23, CIFAR-10 Batch 3:  Loss:     0.3969 Validation Accuracy: 0.598000
# Epoch 23, CIFAR-10 Batch 4:  Loss:     0.4309 Validation Accuracy: 0.606600
# Epoch 23, CIFAR-10 Batch 5:  Loss:     0.3967 Validation Accuracy: 0.608400
# Epoch 24, CIFAR-10 Batch 1:  Loss:     0.6036 Validation Accuracy: 0.608400
# Epoch 24, CIFAR-10 Batch 2:  Loss:     0.4761 Validation Accuracy: 0.593800
# Epoch 24, CIFAR-10 Batch 3:  Loss:     0.3756 Validation Accuracy: 0.601200
# Epoch 24, CIFAR-10 Batch 4:  Loss:     0.4478 Validation Accuracy: 0.607400
# Epoch 24, CIFAR-10 Batch 5:  Loss:     0.3589 Validation Accuracy: 0.611000
# Epoch 25, CIFAR-10 Batch 1:  Loss:     0.5945 Validation Accuracy: 0.604600
# Epoch 25, CIFAR-10 Batch 2:  Loss:     0.4156 Validation Accuracy: 0.596600
# Epoch 25, CIFAR-10 Batch 3:  Loss:     0.3675 Validation Accuracy: 0.596400
# Epoch 25, CIFAR-10 Batch 4:  Loss:     0.3981 Validation Accuracy: 0.607600
# Epoch 25, CIFAR-10 Batch 5:  Loss:     0.3566 Validation Accuracy: 0.610800
# Epoch 26, CIFAR-10 Batch 1:  Loss:     0.5564 Validation Accuracy: 0.612400
# Epoch 26, CIFAR-10 Batch 2:  Loss:     0.4136 Validation Accuracy: 0.602000
# Epoch 26, CIFAR-10 Batch 3:  Loss:     0.3216 Validation Accuracy: 0.598200
# Epoch 26, CIFAR-10 Batch 4:  Loss:     0.4007 Validation Accuracy: 0.606800
# Epoch 26, CIFAR-10 Batch 5:  Loss:     0.3318 Validation Accuracy: 0.614600
# Epoch 27, CIFAR-10 Batch 1:  Loss:     0.5440 Validation Accuracy: 0.613400
# Epoch 27, CIFAR-10 Batch 2:  Loss:     0.3632 Validation Accuracy: 0.600000
# Epoch 27, CIFAR-10 Batch 3:  Loss:     0.3092 Validation Accuracy: 0.596800
# Epoch 27, CIFAR-10 Batch 4:  Loss:     0.3932 Validation Accuracy: 0.611600
# Epoch 27, CIFAR-10 Batch 5:  Loss:     0.3234 Validation Accuracy: 0.616200
# Epoch 28, CIFAR-10 Batch 1:  Loss:     0.5368 Validation Accuracy: 0.606400
# Epoch 28, CIFAR-10 Batch 2:  Loss:     0.3489 Validation Accuracy: 0.606800
# Epoch 28, CIFAR-10 Batch 3:  Loss:     0.3027 Validation Accuracy: 0.604600
# Epoch 28, CIFAR-10 Batch 4:  Loss:     0.3890 Validation Accuracy: 0.601200
# Epoch 28, CIFAR-10 Batch 5:  Loss:     0.3445 Validation Accuracy: 0.607600
# Epoch 29, CIFAR-10 Batch 1:  Loss:     0.5356 Validation Accuracy: 0.611800
# Epoch 29, CIFAR-10 Batch 2:  Loss:     0.3552 Validation Accuracy: 0.605400
# Epoch 29, CIFAR-10 Batch 3:  Loss:     0.2772 Validation Accuracy: 0.606400
# Epoch 29, CIFAR-10 Batch 4:  Loss:     0.3381 Validation Accuracy: 0.610800
# Epoch 29, CIFAR-10 Batch 5:  Loss:     0.2867 Validation Accuracy: 0.611000
# Epoch 30, CIFAR-10 Batch 1:  Loss:     0.5237 Validation Accuracy: 0.606000
# Epoch 30, CIFAR-10 Batch 2:  Loss:     0.3332 Validation Accuracy: 0.606800
# Epoch 30, CIFAR-10 Batch 3:  Loss:     0.2745 Validation Accuracy: 0.610000
# Epoch 30, CIFAR-10 Batch 4:  Loss:     0.3425 Validation Accuracy: 0.610400
# Epoch 30, CIFAR-10 Batch 5:  Loss:     0.2894 Validation Accuracy: 0.612200
# Epoch 31, CIFAR-10 Batch 1:  Loss:     0.4948 Validation Accuracy: 0.606400
# Epoch 31, CIFAR-10 Batch 2:  Loss:     0.3216 Validation Accuracy: 0.609600
# Epoch 31, CIFAR-10 Batch 3:  Loss:     0.2507 Validation Accuracy: 0.607600
# Epoch 31, CIFAR-10 Batch 4:  Loss:     0.3417 Validation Accuracy: 0.605000
# Epoch 31, CIFAR-10 Batch 5:  Loss:     0.2659 Validation Accuracy: 0.613000
# Epoch 32, CIFAR-10 Batch 1:  Loss:     0.4716 Validation Accuracy: 0.602600
# Epoch 32, CIFAR-10 Batch 2:  Loss:     0.2931 Validation Accuracy: 0.601600
# Epoch 32, CIFAR-10 Batch 3:  Loss:     0.2496 Validation Accuracy: 0.606800
# Epoch 32, CIFAR-10 Batch 4:  Loss:     0.3369 Validation Accuracy: 0.604800
# Epoch 32, CIFAR-10 Batch 5:  Loss:     0.2567 Validation Accuracy: 0.612800
# Epoch 33, CIFAR-10 Batch 1:  Loss:     0.4655 Validation Accuracy: 0.604600
# Epoch 33, CIFAR-10 Batch 2:  Loss:     0.3196 Validation Accuracy: 0.604000
# Epoch 33, CIFAR-10 Batch 3:  Loss:     0.2391 Validation Accuracy: 0.608000
# Epoch 33, CIFAR-10 Batch 4:  Loss:     0.3140 Validation Accuracy: 0.608200
# Epoch 33, CIFAR-10 Batch 5:  Loss:     0.2679 Validation Accuracy: 0.614200
# Epoch 34, CIFAR-10 Batch 1:  Loss:     0.4516 Validation Accuracy: 0.607400
# Epoch 34, CIFAR-10 Batch 2:  Loss:     0.2922 Validation Accuracy: 0.607400
# Epoch 34, CIFAR-10 Batch 3:  Loss:     0.2381 Validation Accuracy: 0.611400
# Epoch 34, CIFAR-10 Batch 4:  Loss:     0.3271 Validation Accuracy: 0.603000
# Epoch 34, CIFAR-10 Batch 5:  Loss:     0.2678 Validation Accuracy: 0.612800
# Epoch 35, CIFAR-10 Batch 1:  Loss:     0.4505 Validation Accuracy: 0.604400
# Epoch 35, CIFAR-10 Batch 2:  Loss:     0.2909 Validation Accuracy: 0.601400
# Epoch 35, CIFAR-10 Batch 3:  Loss:     0.2365 Validation Accuracy: 0.606800
# Epoch 35, CIFAR-10 Batch 4:  Loss:     0.2846 Validation Accuracy: 0.605200
# Epoch 35, CIFAR-10 Batch 5:  Loss:     0.2268 Validation Accuracy: 0.611400
# Epoch 36, CIFAR-10 Batch 1:  Loss:     0.4255 Validation Accuracy: 0.598800
# Epoch 36, CIFAR-10 Batch 2:  Loss:     0.2599 Validation Accuracy: 0.608600
# Epoch 36, CIFAR-10 Batch 3:  Loss:     0.2110 Validation Accuracy: 0.603600
# Epoch 36, CIFAR-10 Batch 4:  Loss:     0.2971 Validation Accuracy: 0.599200
# Epoch 36, CIFAR-10 Batch 5:  Loss:     0.2180 Validation Accuracy: 0.614800
# Epoch 37, CIFAR-10 Batch 1:  Loss:     0.4051 Validation Accuracy: 0.604200
# Epoch 37, CIFAR-10 Batch 2:  Loss:     0.2855 Validation Accuracy: 0.605600
# Epoch 37, CIFAR-10 Batch 3:  Loss:     0.2174 Validation Accuracy: 0.607600
# Epoch 37, CIFAR-10 Batch 4:  Loss:     0.2832 Validation Accuracy: 0.603200
# Epoch 37, CIFAR-10 Batch 5:  Loss:     0.2378 Validation Accuracy: 0.611200
# Epoch 38, CIFAR-10 Batch 1:  Loss:     0.4212 Validation Accuracy: 0.597800
# Epoch 38, CIFAR-10 Batch 2:  Loss:     0.2857 Validation Accuracy: 0.603800
# Epoch 38, CIFAR-10 Batch 3:  Loss:     0.2105 Validation Accuracy: 0.606600
# Epoch 38, CIFAR-10 Batch 4:  Loss:     0.2608 Validation Accuracy: 0.610200
# Epoch 38, CIFAR-10 Batch 5:  Loss:     0.2080 Validation Accuracy: 0.613800
# Epoch 39, CIFAR-10 Batch 1:  Loss:     0.3905 Validation Accuracy: 0.603000
# Epoch 39, CIFAR-10 Batch 2:  Loss:     0.2478 Validation Accuracy: 0.608000
# Epoch 39, CIFAR-10 Batch 3:  Loss:     0.1929 Validation Accuracy: 0.605400
# Epoch 39, CIFAR-10 Batch 4:  Loss:     0.2434 Validation Accuracy: 0.606800
# Epoch 39, CIFAR-10 Batch 5:  Loss:     0.1951 Validation Accuracy: 0.610800
# Epoch 40, CIFAR-10 Batch 1:  Loss:     0.3929 Validation Accuracy: 0.602000
# Epoch 40, CIFAR-10 Batch 2:  Loss:     0.2326 Validation Accuracy: 0.604800
# Epoch 40, CIFAR-10 Batch 3:  Loss:     0.1882 Validation Accuracy: 0.605800
# Epoch 40, CIFAR-10 Batch 4:  Loss:     0.2654 Validation Accuracy: 0.600400
# Epoch 40, CIFAR-10 Batch 5:  Loss:     0.2175 Validation Accuracy: 0.609400
# Epoch 41, CIFAR-10 Batch 1:  Loss:     0.3598 Validation Accuracy: 0.602200
# Epoch 41, CIFAR-10 Batch 2:  Loss:     0.2186 Validation Accuracy: 0.608600
# Epoch 41, CIFAR-10 Batch 3:  Loss:     0.1890 Validation Accuracy: 0.607600
# Epoch 41, CIFAR-10 Batch 4:  Loss:     0.2316 Validation Accuracy: 0.604600
# Epoch 41, CIFAR-10 Batch 5:  Loss:     0.1929 Validation Accuracy: 0.611600
# Epoch 42, CIFAR-10 Batch 1:  Loss:     0.3546 Validation Accuracy: 0.607400
# Epoch 42, CIFAR-10 Batch 2:  Loss:     0.2061 Validation Accuracy: 0.605600
# Epoch 42, CIFAR-10 Batch 3:  Loss:     0.2146 Validation Accuracy: 0.605600
# Epoch 42, CIFAR-10 Batch 4:  Loss:     0.2320 Validation Accuracy: 0.601800
# Epoch 42, CIFAR-10 Batch 5:  Loss:     0.1813 Validation Accuracy: 0.607800
# Epoch 43, CIFAR-10 Batch 1:  Loss:     0.3444 Validation Accuracy: 0.598400
# Epoch 43, CIFAR-10 Batch 2:  Loss:     0.1901 Validation Accuracy: 0.604400
# Epoch 43, CIFAR-10 Batch 3:  Loss:     0.1985 Validation Accuracy: 0.598600
# Epoch 43, CIFAR-10 Batch 4:  Loss:     0.2402 Validation Accuracy: 0.596800
# Epoch 43, CIFAR-10 Batch 5:  Loss:     0.1679 Validation Accuracy: 0.608000
# Epoch 44, CIFAR-10 Batch 1:  Loss:     0.3352 Validation Accuracy: 0.604800
# Epoch 44, CIFAR-10 Batch 2:  Loss:     0.1818 Validation Accuracy: 0.601200
# Epoch 44, CIFAR-10 Batch 3:  Loss:     0.2039 Validation Accuracy: 0.597000
# Epoch 44, CIFAR-10 Batch 4:  Loss:     0.2247 Validation Accuracy: 0.606600
# Epoch 44, CIFAR-10 Batch 5:  Loss:     0.1841 Validation Accuracy: 0.609600
# Epoch 45, CIFAR-10 Batch 1:  Loss:     0.3138 Validation Accuracy: 0.600200
# Epoch 45, CIFAR-10 Batch 2:  Loss:     0.1859 Validation Accuracy: 0.613200
# Epoch 45, CIFAR-10 Batch 3:  Loss:     0.1767 Validation Accuracy: 0.601600
# Epoch 45, CIFAR-10 Batch 4:  Loss:     0.2333 Validation Accuracy: 0.594400
# Epoch 45, CIFAR-10 Batch 5:  Loss:     0.1640 Validation Accuracy: 0.605600
# Epoch 46, CIFAR-10 Batch 1:  Loss:     0.3225 Validation Accuracy: 0.603200
# Epoch 46, CIFAR-10 Batch 2:  Loss:     0.1685 Validation Accuracy: 0.604400
# Epoch 46, CIFAR-10 Batch 3:  Loss:     0.1726 Validation Accuracy: 0.600800
# Epoch 46, CIFAR-10 Batch 4:  Loss:     0.2272 Validation Accuracy: 0.592600
# Epoch 46, CIFAR-10 Batch 5:  Loss:     0.1558 Validation Accuracy: 0.604800
# Epoch 47, CIFAR-10 Batch 1:  Loss:     0.3050 Validation Accuracy: 0.597600
# Epoch 47, CIFAR-10 Batch 2:  Loss:     0.1718 Validation Accuracy: 0.603800
# Epoch 47, CIFAR-10 Batch 3:  Loss:     0.1718 Validation Accuracy: 0.599200
# Epoch 47, CIFAR-10 Batch 4:  Loss:     0.2303 Validation Accuracy: 0.596400
# Epoch 47, CIFAR-10 Batch 5:  Loss:     0.1559 Validation Accuracy: 0.601800
# Epoch 48, CIFAR-10 Batch 1:  Loss:     0.3163 Validation Accuracy: 0.604400
# Epoch 48, CIFAR-10 Batch 2:  Loss:     0.1571 Validation Accuracy: 0.603200
# Epoch 48, CIFAR-10 Batch 3:  Loss:     0.1570 Validation Accuracy: 0.606000
# Epoch 48, CIFAR-10 Batch 4:  Loss:     0.2172 Validation Accuracy: 0.600800
# Epoch 48, CIFAR-10 Batch 5:  Loss:     0.1572 Validation Accuracy: 0.607000
# Epoch 49, CIFAR-10 Batch 1:  Loss:     0.3027 Validation Accuracy: 0.597800
# Epoch 49, CIFAR-10 Batch 2:  Loss:     0.1414 Validation Accuracy: 0.607200
# Epoch 49, CIFAR-10 Batch 3:  Loss:     0.1611 Validation Accuracy: 0.602400
# Epoch 49, CIFAR-10 Batch 4:  Loss:     0.2018 Validation Accuracy: 0.603600
# Epoch 49, CIFAR-10 Batch 5:  Loss:     0.1476 Validation Accuracy: 0.606400
# Epoch 50, CIFAR-10 Batch 1:  Loss:     0.2791 Validation Accuracy: 0.605000
# Epoch 50, CIFAR-10 Batch 2:  Loss:     0.1627 Validation Accuracy: 0.607200
# Epoch 50, CIFAR-10 Batch 3:  Loss:     0.1915 Validation Accuracy: 0.601200
# Epoch 50, CIFAR-10 Batch 4:  Loss:     0.1864 Validation Accuracy: 0.601800
# Epoch 50, CIFAR-10 Batch 5:  Loss:     0.1297 Validation Accuracy: 0.605800
# Epoch 51, CIFAR-10 Batch 1:  Loss:     0.2816 Validation Accuracy: 0.600000
# Epoch 51, CIFAR-10 Batch 2:  Loss:     0.1419 Validation Accuracy: 0.604200
# Epoch 51, CIFAR-10 Batch 3:  Loss:     0.1674 Validation Accuracy: 0.600400
# Epoch 51, CIFAR-10 Batch 4:  Loss:     0.1918 Validation Accuracy: 0.595400
# Epoch 51, CIFAR-10 Batch 5:  Loss:     0.1375 Validation Accuracy: 0.604400
# Epoch 52, CIFAR-10 Batch 1:  Loss:     0.2745 Validation Accuracy: 0.603400
# Epoch 52, CIFAR-10 Batch 2:  Loss:     0.1368 Validation Accuracy: 0.598600
# Epoch 52, CIFAR-10 Batch 3:  Loss:     0.1537 Validation Accuracy: 0.599400
# Epoch 52, CIFAR-10 Batch 4:  Loss:     0.1912 Validation Accuracy: 0.601200
# Epoch 52, CIFAR-10 Batch 5:  Loss:     0.1314 Validation Accuracy: 0.605200
# Epoch 53, CIFAR-10 Batch 1:  Loss:     0.2801 Validation Accuracy: 0.603000
# Epoch 53, CIFAR-10 Batch 2:  Loss:     0.1220 Validation Accuracy: 0.599600
# Epoch 53, CIFAR-10 Batch 3:  Loss:     0.1580 Validation Accuracy: 0.601600
# Epoch 53, CIFAR-10 Batch 4:  Loss:     0.1906 Validation Accuracy: 0.600000
# Epoch 53, CIFAR-10 Batch 5:  Loss:     0.1296 Validation Accuracy: 0.610000
# Epoch 54, CIFAR-10 Batch 1:  Loss:     0.2629 Validation Accuracy: 0.607600
# Epoch 54, CIFAR-10 Batch 2:  Loss:     0.1456 Validation Accuracy: 0.607000
# Epoch 54, CIFAR-10 Batch 3:  Loss:     0.1303 Validation Accuracy: 0.603800
# Epoch 54, CIFAR-10 Batch 4:  Loss:     0.1887 Validation Accuracy: 0.597200
# Epoch 54, CIFAR-10 Batch 5:  Loss:     0.1192 Validation Accuracy: 0.609400
# Epoch 55, CIFAR-10 Batch 1:  Loss:     0.2606 Validation Accuracy: 0.597400
# Epoch 55, CIFAR-10 Batch 2:  Loss:     0.1430 Validation Accuracy: 0.601200
# Epoch 55, CIFAR-10 Batch 3:  Loss:     0.1382 Validation Accuracy: 0.604600
# Epoch 55, CIFAR-10 Batch 4:  Loss:     0.1833 Validation Accuracy: 0.600000
# Epoch 55, CIFAR-10 Batch 5:  Loss:     0.1137 Validation Accuracy: 0.607000
# Epoch 56, CIFAR-10 Batch 1:  Loss:     0.2313 Validation Accuracy: 0.602800
# Epoch 56, CIFAR-10 Batch 2:  Loss:     0.1305 Validation Accuracy: 0.603200
# Epoch 56, CIFAR-10 Batch 3:  Loss:     0.1296 Validation Accuracy: 0.604600
# Epoch 56, CIFAR-10 Batch 4:  Loss:     0.2039 Validation Accuracy: 0.591400
# Epoch 56, CIFAR-10 Batch 5:  Loss:     0.1189 Validation Accuracy: 0.607600
# Epoch 57, CIFAR-10 Batch 1:  Loss:     0.2541 Validation Accuracy: 0.596800
# Epoch 57, CIFAR-10 Batch 2:  Loss:     0.1292 Validation Accuracy: 0.606600
# Epoch 57, CIFAR-10 Batch 3:  Loss:     0.1234 Validation Accuracy: 0.602600
# Epoch 57, CIFAR-10 Batch 4:  Loss:     0.1794 Validation Accuracy: 0.599800
# Epoch 57, CIFAR-10 Batch 5:  Loss:     0.1179 Validation Accuracy: 0.605600
# Epoch 58, CIFAR-10 Batch 1:  Loss:     0.2392 Validation Accuracy: 0.588600
# Epoch 58, CIFAR-10 Batch 2:  Loss:     0.1198 Validation Accuracy: 0.602400
# Epoch 58, CIFAR-10 Batch 3:  Loss:     0.1202 Validation Accuracy: 0.604200
# Epoch 58, CIFAR-10 Batch 4:  Loss:     0.1800 Validation Accuracy: 0.598800
# Epoch 58, CIFAR-10 Batch 5:  Loss:     0.1189 Validation Accuracy: 0.604200
# Epoch 59, CIFAR-10 Batch 1:  Loss:     0.2114 Validation Accuracy: 0.592600
# Epoch 59, CIFAR-10 Batch 2:  Loss:     0.1143 Validation Accuracy: 0.603800
# Epoch 59, CIFAR-10 Batch 3:  Loss:     0.1135 Validation Accuracy: 0.602800
# Epoch 59, CIFAR-10 Batch 4:  Loss:     0.1707 Validation Accuracy: 0.598800
# Epoch 59, CIFAR-10 Batch 5:  Loss:     0.1076 Validation Accuracy: 0.604200
# Epoch 60, CIFAR-10 Batch 1:  Loss:     0.2091 Validation Accuracy: 0.594600
# Epoch 60, CIFAR-10 Batch 2:  Loss:     0.1225 Validation Accuracy: 0.598200
# Epoch 60, CIFAR-10 Batch 3:  Loss:     0.1070 Validation Accuracy: 0.603200
# Epoch 60, CIFAR-10 Batch 4:  Loss:     0.1662 Validation Accuracy: 0.597200
# Epoch 60, CIFAR-10 Batch 5:  Loss:     0.1093 Validation Accuracy: 0.602200
# Epoch 61, CIFAR-10 Batch 1:  Loss:     0.2228 Validation Accuracy: 0.591000
# Epoch 61, CIFAR-10 Batch 2:  Loss:     0.1240 Validation Accuracy: 0.601800
# Epoch 61, CIFAR-10 Batch 3:  Loss:     0.1294 Validation Accuracy: 0.598800
# Epoch 61, CIFAR-10 Batch 4:  Loss:     0.1874 Validation Accuracy: 0.597800
# Epoch 61, CIFAR-10 Batch 5:  Loss:     0.1006 Validation Accuracy: 0.604600
# Epoch 62, CIFAR-10 Batch 1:  Loss:     0.2091 Validation Accuracy: 0.592200
# Epoch 62, CIFAR-10 Batch 2:  Loss:     0.1206 Validation Accuracy: 0.599600
# Epoch 62, CIFAR-10 Batch 3:  Loss:     0.1094 Validation Accuracy: 0.600000
# Epoch 62, CIFAR-10 Batch 4:  Loss:     0.1738 Validation Accuracy: 0.600400
# Epoch 62, CIFAR-10 Batch 5:  Loss:     0.0998 Validation Accuracy: 0.606800
# Epoch 63, CIFAR-10 Batch 1:  Loss:     0.2078 Validation Accuracy: 0.593600
# Epoch 63, CIFAR-10 Batch 2:  Loss:     0.1196 Validation Accuracy: 0.598400
# Epoch 63, CIFAR-10 Batch 3:  Loss:     0.1192 Validation Accuracy: 0.603400
# Epoch 63, CIFAR-10 Batch 4:  Loss:     0.1741 Validation Accuracy: 0.591400
# Epoch 63, CIFAR-10 Batch 5:  Loss:     0.0891 Validation Accuracy: 0.606600
# Epoch 64, CIFAR-10 Batch 1:  Loss:     0.1863 Validation Accuracy: 0.597400
# Epoch 64, CIFAR-10 Batch 2:  Loss:     0.1215 Validation Accuracy: 0.601400
# Epoch 64, CIFAR-10 Batch 3:  Loss:     0.1170 Validation Accuracy: 0.602600
# Epoch 64, CIFAR-10 Batch 4:  Loss:     0.1596 Validation Accuracy: 0.592400
# Epoch 64, CIFAR-10 Batch 5:  Loss:     0.1076 Validation Accuracy: 0.602400
# Epoch 65, CIFAR-10 Batch 1:  Loss:     0.1856 Validation Accuracy: 0.593000
# Epoch 65, CIFAR-10 Batch 2:  Loss:     0.1167 Validation Accuracy: 0.602000
# Epoch 65, CIFAR-10 Batch 3:  Loss:     0.1071 Validation Accuracy: 0.599800
# Epoch 65, CIFAR-10 Batch 4:  Loss:     0.1746 Validation Accuracy: 0.597400
# Epoch 65, CIFAR-10 Batch 5:  Loss:     0.0936 Validation Accuracy: 0.606800
# Epoch 66, CIFAR-10 Batch 1:  Loss:     0.1919 Validation Accuracy: 0.593600
# Epoch 66, CIFAR-10 Batch 2:  Loss:     0.1260 Validation Accuracy: 0.600600
# Epoch 66, CIFAR-10 Batch 3:  Loss:     0.1166 Validation Accuracy: 0.594400
# Epoch 66, CIFAR-10 Batch 4:  Loss:     0.1634 Validation Accuracy: 0.595800
# Epoch 66, CIFAR-10 Batch 5:  Loss:     0.0909 Validation Accuracy: 0.602200
# Epoch 67, CIFAR-10 Batch 1:  Loss:     0.1722 Validation Accuracy: 0.596200
# Epoch 67, CIFAR-10 Batch 2:  Loss:     0.1200 Validation Accuracy: 0.603200
# Epoch 67, CIFAR-10 Batch 3:  Loss:     0.1137 Validation Accuracy: 0.594400
# Epoch 67, CIFAR-10 Batch 4:  Loss:     0.1543 Validation Accuracy: 0.597600
# Epoch 67, CIFAR-10 Batch 5:  Loss:     0.0941 Validation Accuracy: 0.601400
# Epoch 68, CIFAR-10 Batch 1:  Loss:     0.1723 Validation Accuracy: 0.594600
# Epoch 68, CIFAR-10 Batch 2:  Loss:     0.1170 Validation Accuracy: 0.602400
# Epoch 68, CIFAR-10 Batch 3:  Loss:     0.1048 Validation Accuracy: 0.596200
# Epoch 68, CIFAR-10 Batch 4:  Loss:     0.1471 Validation Accuracy: 0.599000
# Epoch 68, CIFAR-10 Batch 5:  Loss:     0.1034 Validation Accuracy: 0.602600
# Epoch 69, CIFAR-10 Batch 1:  Loss:     0.1899 Validation Accuracy: 0.592200
# Epoch 69, CIFAR-10 Batch 2:  Loss:     0.1086 Validation Accuracy: 0.599200
# Epoch 69, CIFAR-10 Batch 3:  Loss:     0.0931 Validation Accuracy: 0.595000
# Epoch 69, CIFAR-10 Batch 4:  Loss:     0.1496 Validation Accuracy: 0.597800
# Epoch 69, CIFAR-10 Batch 5:  Loss:     0.0865 Validation Accuracy: 0.602600
# Epoch 70, CIFAR-10 Batch 1:  Loss:     0.1521 Validation Accuracy: 0.590800
# Epoch 70, CIFAR-10 Batch 2:  Loss:     0.1129 Validation Accuracy: 0.596200
# Epoch 70, CIFAR-10 Batch 3:  Loss:     0.0921 Validation Accuracy: 0.598600
# Epoch 70, CIFAR-10 Batch 4:  Loss:     0.1677 Validation Accuracy: 0.592800
# Epoch 70, CIFAR-10 Batch 5:  Loss:     0.0882 Validation Accuracy: 0.605400
# Epoch 71, CIFAR-10 Batch 1:  Loss:     0.2036 Validation Accuracy: 0.583600
# Epoch 71, CIFAR-10 Batch 2:  Loss:     0.1139 Validation Accuracy: 0.604600
# Epoch 71, CIFAR-10 Batch 3:  Loss:     0.0962 Validation Accuracy: 0.591600
# Epoch 71, CIFAR-10 Batch 4:  Loss:     0.1366 Validation Accuracy: 0.593200
# Epoch 71, CIFAR-10 Batch 5:  Loss:     0.0775 Validation Accuracy: 0.604400
# Epoch 72, CIFAR-10 Batch 1:  Loss:     0.1582 Validation Accuracy: 0.586000
# Epoch 72, CIFAR-10 Batch 2:  Loss:     0.0961 Validation Accuracy: 0.599800
# Epoch 72, CIFAR-10 Batch 3:  Loss:     0.0980 Validation Accuracy: 0.590000
# Epoch 72, CIFAR-10 Batch 4:  Loss:     0.1669 Validation Accuracy: 0.590000
# Epoch 72, CIFAR-10 Batch 5:  Loss:     0.0708 Validation Accuracy: 0.600000
# Epoch 73, CIFAR-10 Batch 1:  Loss:     0.1539 Validation Accuracy: 0.594600
# Epoch 73, CIFAR-10 Batch 2:  Loss:     0.0826 Validation Accuracy: 0.599600
# Epoch 73, CIFAR-10 Batch 3:  Loss:     0.0953 Validation Accuracy: 0.597400
# Epoch 73, CIFAR-10 Batch 4:  Loss:     0.1567 Validation Accuracy: 0.595600
# Epoch 73, CIFAR-10 Batch 5:  Loss:     0.0747 Validation Accuracy: 0.594800
# Epoch 74, CIFAR-10 Batch 1:  Loss:     0.1585 Validation Accuracy: 0.593400
# Epoch 74, CIFAR-10 Batch 2:  Loss:     0.0925 Validation Accuracy: 0.600600
# Epoch 74, CIFAR-10 Batch 3:  Loss:     0.0981 Validation Accuracy: 0.594200
# Epoch 74, CIFAR-10 Batch 4:  Loss:     0.1491 Validation Accuracy: 0.590000
# Epoch 74, CIFAR-10 Batch 5:  Loss:     0.0825 Validation Accuracy: 0.596400
# Epoch 75, CIFAR-10 Batch 1:  Loss:     0.1503 Validation Accuracy: 0.585000
# Epoch 75, CIFAR-10 Batch 2:  Loss:     0.0895 Validation Accuracy: 0.593800
# Epoch 75, CIFAR-10 Batch 3:  Loss:     0.1026 Validation Accuracy: 0.594400
# Epoch 75, CIFAR-10 Batch 4:  Loss:     0.1480 Validation Accuracy: 0.595200
# Epoch 75, CIFAR-10 Batch 5:  Loss:     0.0902 Validation Accuracy: 0.604400
# Epoch 76, CIFAR-10 Batch 1:  Loss:     0.1521 Validation Accuracy: 0.591000
# Epoch 76, CIFAR-10 Batch 2:  Loss:     0.1002 Validation Accuracy: 0.595000
# Epoch 76, CIFAR-10 Batch 3:  Loss:     0.0909 Validation Accuracy: 0.596200
# Epoch 76, CIFAR-10 Batch 4:  Loss:     0.1385 Validation Accuracy: 0.593200
# Epoch 76, CIFAR-10 Batch 5:  Loss:     0.0834 Validation Accuracy: 0.600400
# Epoch 77, CIFAR-10 Batch 1:  Loss:     0.1540 Validation Accuracy: 0.590200
# Epoch 77, CIFAR-10 Batch 2:  Loss:     0.0925 Validation Accuracy: 0.592800
# Epoch 77, CIFAR-10 Batch 3:  Loss:     0.0844 Validation Accuracy: 0.591800
# Epoch 77, CIFAR-10 Batch 4:  Loss:     0.1510 Validation Accuracy: 0.594600
# Epoch 77, CIFAR-10 Batch 5:  Loss:     0.0878 Validation Accuracy: 0.597400
# Epoch 78, CIFAR-10 Batch 1:  Loss:     0.1332 Validation Accuracy: 0.596200
# Epoch 78, CIFAR-10 Batch 2:  Loss:     0.0928 Validation Accuracy: 0.601000
# Epoch 78, CIFAR-10 Batch 3:  Loss:     0.0981 Validation Accuracy: 0.593600
# Epoch 78, CIFAR-10 Batch 4:  Loss:     0.1507 Validation Accuracy: 0.589800
# Epoch 78, CIFAR-10 Batch 5:  Loss:     0.0786 Validation Accuracy: 0.593600
# Epoch 79, CIFAR-10 Batch 1:  Loss:     0.1556 Validation Accuracy: 0.587400
# Epoch 79, CIFAR-10 Batch 2:  Loss:     0.0830 Validation Accuracy: 0.592400
# Epoch 79, CIFAR-10 Batch 3:  Loss:     0.0995 Validation Accuracy: 0.588000
# Epoch 79, CIFAR-10 Batch 4:  Loss:     0.1397 Validation Accuracy: 0.586400
# Epoch 79, CIFAR-10 Batch 5:  Loss:     0.0694 Validation Accuracy: 0.599400
# Epoch 80, CIFAR-10 Batch 1:  Loss:     0.1435 Validation Accuracy: 0.589600
# Epoch 80, CIFAR-10 Batch 2:  Loss:     0.0643 Validation Accuracy: 0.596800
# Epoch 80, CIFAR-10 Batch 3:  Loss:     0.0909 Validation Accuracy: 0.587800
# Epoch 80, CIFAR-10 Batch 4:  Loss:     0.1321 Validation Accuracy: 0.591600
# Epoch 80, CIFAR-10 Batch 5:  Loss:     0.0756 Validation Accuracy: 0.604600

# %% [markdown]
# # Checkpoint
# The model has been saved to disk.
# ## Test Model
# Test your model against the test dataset.  This will be your final accuracy. You should have an accuracy greater than 50%. If you don't, keep tweaking the model architecture and parameters.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import tensorflow as tf
import pickle
import helper
import random

# Set batch size if not already set
try:
    if batch_size:
        pass
except NameError:
    batch_size = 64

save_model_path = './image_classification'
n_samples = 4
top_n_predictions = 3

def test_model():
    """
    Test the saved model against the test dataset
    """

    test_features, test_labels = pickle.load(open('preprocess_test.p', mode='rb'))
    loaded_graph = tf.Graph()

    with tf.Session(graph=loaded_graph) as sess:
        # Load model
        loader = tf.train.import_meta_graph(save_model_path + '.meta')
        loader.restore(sess, save_model_path)

        # Get Tensors from loaded model
        loaded_x = loaded_graph.get_tensor_by_name('x:0')
        loaded_y = loaded_graph.get_tensor_by_name('y:0')
        loaded_keep_prob = loaded_graph.get_tensor_by_name('keep_prob:0')
        loaded_logits = loaded_graph.get_tensor_by_name('logits:0')
        loaded_acc = loaded_graph.get_tensor_by_name('accuracy:0')
        
        # Get accuracy in batches for memory limitations
        test_batch_acc_total = 0
        test_batch_count = 0
        
        for test_feature_batch, test_label_batch in helper.batch_features_labels(test_features, test_labels, batch_size):
            test_batch_acc_total += sess.run(
                loaded_acc,
                feed_dict={loaded_x: test_feature_batch, loaded_y: test_label_batch, loaded_keep_prob: 1.0})
            test_batch_count += 1

        print('Testing Accuracy: {}\n'.format(test_batch_acc_total/test_batch_count))

        # Print Random Samples
        random_test_features, random_test_labels = tuple(zip(*random.sample(list(zip(test_features, test_labels)), n_samples)))
        random_test_predictions = sess.run(
            tf.nn.top_k(tf.nn.softmax(loaded_logits), top_n_predictions),
            feed_dict={loaded_x: random_test_features, loaded_y: random_test_labels, loaded_keep_prob: 1.0})
        helper.display_image_predictions(random_test_features, random_test_labels, random_test_predictions)


test_model()
# Out:
# INFO:tensorflow:Restoring parameters from ./image_classification
# Testing Accuracy: 0.5959256329113924

# %% [markdown]
# ## Why 50-80% Accuracy?
# You might be wondering why you can't get an accuracy any higher. First things first, 50% isn't bad for a simple CNN.  Pure guessing would get you 10% accuracy. However, you might notice people are getting scores [well above 80%](http://rodrigob.github.io/are_we_there_yet/build/classification_datasets_results.html#43494641522d3130).  That's because we haven't taught you all there is to know about neural networks. We still need to cover a few more techniques.
# ## Submitting This Project
# When submitting this project, make sure to run all the cells before saving the notebook.  Save the notebook file as "dlnd_image_classification.ipynb" and save it as a HTML file under "File" -> "Download as".  Include the "helper.py" and "problem_unittests.py" files in your submission.
